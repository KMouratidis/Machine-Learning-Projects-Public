# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats.stats import pearsonr
from feather import read_dataframe
# %matplotlib inline

# %% [raw]
# ratings = pd.read_csv("/media/kmourat/Elements/Datasets/Recommender-Datasets/Books/BX-Book-Ratings.csv",
#                       sep=';', escapechar='\\', encoding='CP1252', )
# books = pd.read_csv("/media/kmourat/Elements/Datasets/Recommender-Datasets/Books/BX-Books.csv",
#                       sep=';', escapechar='\\', encoding='CP1252', )
# users = pd.read_csv("/media/kmourat/Elements/Datasets/Recommender-Datasets/Books/BX-Users.csv",
#                       sep=';', escapechar='\\', encoding='CP1252', )
#
# users["User-ID"] = users["User-ID"].apply(lambda x: f"User_{x}")
# ratings["User-ID"] = ratings["User-ID"].apply(lambda x: f"User_{x}")
# # books.fillna("N/A", inplace=True)
# # users.fillna("N/A", inplace=True)
#
# ratings = ratings.set_index("User-ID")[ratings["User-ID"].value_counts()>=10].reset_index()
# ratings = ratings.set_index("ISBN")[ratings["ISBN"].value_counts()>=10].reset_index()
#
# complete = ratings.merge(users, on="User-ID",
#                         ).merge(books, on="ISBN",
#                                )[["User-ID", "Book-Title", "Book-Rating"]]
#
#
# complete["Book-Rating"] = complete["Book-Rating"].astype(np.int8)
#
# complete.to_feather("user_book_ratings.feather")
#
# complete = None
# ratings = None
# books = None
# users = None

# %%
complete = read_dataframe("user_book_ratings.feather",).pivot_table("Book-Rating",
                                                                    index="User-ID",
                                                                    columns="Book-Title")

# %%
complete.head(10)
# Out:
# Book-Title    Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title    Q-Space (Star Trek The Next Generation, Book 47)  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title    Q-Zone (Star Trek The Next Generation, Book 48)  \
# User-ID
# User_100004                                               NaN
# User_100009                                               NaN
# User_10001                                                NaN
# User_100010                                               NaN
# User_100038                                               NaN
# User_100053                                               NaN
# User_100066                                               NaN
# User_100088                                               NaN
# User_100098                                               NaN
# User_100115                                               NaN
#
# Book-Title   " Lamb to the Slaughter and Other Stories (Penguin 60s S.)  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title   "A" is for Alibi : A Kinsey Millhone Mystery (A Kinsey Millhone Mystery)  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title   "O" Is for Outlaw  \
# User-ID
# User_100004                NaN
# User_100009                NaN
# User_10001                 NaN
# User_100010                NaN
# User_100038                NaN
# User_100053                NaN
# User_100066                NaN
# User_100088                NaN
# User_100098                NaN
# User_100115                NaN
#
# Book-Title   "Surely You're Joking, Mr. Feynman!": Adventures of a Curious Character  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title   "The Happy Prince" and Other Stories (Penguin Popular Classics)  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title   'Salem's Lot  \
# User-ID
# User_100004           NaN
# User_100009           NaN
# User_10001            NaN
# User_100010           NaN
# User_100038           NaN
# User_100053           NaN
# User_100066           NaN
# User_100088           NaN
# User_100098           NaN
# User_100115           NaN
#
# Book-Title   ...AND THE HORSE HE RODE IN ON : THE PEOPLE V. KENNETH STARR  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title     ...     Zodiac: The Eco-Thriller  \
# User-ID        ...
# User_100004    ...                          NaN
# User_100009    ...                          NaN
# User_10001     ...                          NaN
# User_100010    ...                          NaN
# User_100038    ...                          NaN
# User_100053    ...                          NaN
# User_100066    ...                          NaN
# User_100088    ...                          NaN
# User_100098    ...                          NaN
# User_100115    ...                          NaN
#
# Book-Title   Zoey Phillips (Girlfriends) (Harlequin Superromance, No. 1020)  \
# User-ID
# User_100004                                                NaN
# User_100009                                                NaN
# User_10001                                                 NaN
# User_100010                                                NaN
# User_100038                                                NaN
# User_100053                                                NaN
# User_100066                                                NaN
# User_100088                                                NaN
# User_100098                                                NaN
# User_100115                                                NaN
#
# Book-Title   Zombies of the Gene Pool  Zoya  \
# User-ID
# User_100004                       NaN   NaN
# User_100009                       NaN   NaN
# User_10001                        NaN   NaN
# User_100010                       NaN   NaN
# User_100038                       NaN   NaN
# User_100053                       NaN   NaN
# User_100066                       NaN   NaN
# User_100088                       NaN   NaN
# User_100098                       NaN   NaN
# User_100115                       NaN   NaN
#
# Book-Title   Zoya's Story: An Afghan Woman's Struggle for Freedom  ZwÃ?Â¶lf.  \
# User-ID
# User_100004                                                NaN           NaN
# User_100009                                                NaN           NaN
# User_10001                                                 NaN           NaN
# User_100010                                                NaN           NaN
# User_100038                                                NaN           NaN
# User_100053                                                NaN           NaN
# User_100066                                                NaN           NaN
# User_100088                                                NaN           NaN
# User_100098                                                NaN           NaN
# User_100115                                                NaN           NaN
#
# Book-Title    e  iI Paradiso Degli Orchi  one hundred years of solitude  \
# User-ID
# User_100004 NaN                      NaN                            NaN
# User_100009 NaN                      NaN                            NaN
# User_10001  NaN                      NaN                            NaN
# User_100010 NaN                      NaN                            NaN
# User_100038 NaN                      NaN                            NaN
# User_100053 NaN                      NaN                            NaN
# User_100066 NaN                      NaN                            NaN
# User_100088 NaN                      NaN                            NaN
# User_100098 NaN                      NaN                            NaN
# User_100115 NaN                      NaN                            NaN
#
# Book-Title   stardust
# User-ID
# User_100004       NaN
# User_100009       NaN
# User_10001        NaN
# User_100010       NaN
# User_100038       NaN
# User_100053       NaN
# User_100066       NaN
# User_100088       NaN
# User_100098       NaN
# User_100115       NaN
#
# [10 rows x 13150 columns]

# %%
complete.memory_usage().sum() / 1024 ** 3
# Out:
# 1.2238024920225143

# %% [raw]
# ff3 = i3.T[((~np.isnan(i1)) & (~np.isnan(i3))).any(0)].T
# ff3

# %%
def get_user(i, df):
    """Get row i; should be the same dtype as RowIndex"""
    return df.loc[i].values

def get_item(j, df):
    """Get row j from the transponsed matrix, aka item j"""
    return df.loc[:,j].values

def compute_evaluation_metric(y_true, y_pred, metric="MSE"):
    """Given two vectors computes the selected metric."""
    
    # This works only on the common elements
    # missing values are ignored
    diff = np.subtract(y_true, y_pred)
    
    # Count NaNs in the difference, check for NaNs and 
    # invert that, finally count non-zeros 
    # https://stackoverflow.com/a/21778195/6655150
    N = np.count_nonzero(~np.isnan(diff))
    
    if metric == "MSE":
        distance = (1 / N) * np.nansum( np.power(diff, 2) )
    elif metric == "MAE":
        distance = (1 / N) * np.nansum( np.abs(diff) )
    elif metric == "RMSE":
        distance = np.sqrt((1 / N) * np.nansum( np.power(diff, 2) ))
    return distance


def cos_sim(user, others):
    """
        This is nothing more than the implementation of cosine similarity
        in a way to handle (ignore) missing values. It is about 2-3x faster
        than replacing NaNs with zeros and then using scipy's or sklearn's
        functions. It assumes the input vectors are `atleast_2D`.
    """
    
    # add some numbers for numeric stability
    sum_sq = np.nansum(np.multiply(user, others), axis=1)

    magnitudes = np.multiply(np.sqrt(np.nansum(np.square(user))),
                             np.sqrt(np.nansum(np.square(others), axis=1))) 
    
    # calculate cosing similarity and add 
    # a small amount to avoid division by 0
    return np.divide(sum_sq+1e-7, magnitudes+1e-3).reshape((user.shape[0], -1))

def pearson_sim(user, others):
    """
        Similarly to the calculation of cosine similarity, this custom approach
        is faster (~1.5x) than filling the whole matrix (this time with the row
        mean) and then using `scipy.stats.stats.pearsonr` with a list comprehension
        iterating over all the rows.
    """
    
    user_mean = np.nanmean(user)
    others_means = np.nanmean(others, axis=1, keepdims=True)

    diff1 = np.subtract( user, user_mean ) 
    diff2 = np.subtract( others, others_means )

    var1 = np.sqrt( np.nansum( np.power(diff1, 2) ) )
    var2 = np.sqrt( np.nansum( np.power(diff2, 2), axis=1, 
                               keepdims=True) )

    num = np.nansum( np.multiply( diff1, diff2 ), axis=1,
                     keepdims=True )
    denom = np.multiply( var1, var2 )
    
    return np.divide(num, (denom + 1e-3)).reshape((user.shape[0], -1))

def similirity_evaluation(user, others, method="pearson"):
    """
        Given two vectors, or a vector and list of vectors, computes
        the selected similarity metric(s).
    """
    
    # make sure they are in the correct shape
    user = np.atleast_2d(user)
    others = np.atleast_2d(others)

    if method == "pearson":
        return pearson_sim(user, others)
    
    elif method == "cosine":
        return cos_sim(user, others)
    
def predict_user_ratings(user, others):
    
    # make sure the shape is correct
    user = np.atleast_2d(user)
    others = np.atleast_2d(others)

    # use numpy to calculate the mean ignoring NaNs
    user_mean = np.nanmean(user)
    others_means =  np.nanmean(others, axis=1, keepdims=True)
    
    diff2 = np.subtract( others, others_means )
    similarities = similirity_evaluation(user, others, "cosine")
    
    num = np.nansum( np.multiply(similarities.T, diff2), axis=0 )
    denom = np.nansum(similarities)
            
    return np.add(user_mean, np.multiply(num, 1/(denom + 1e-4)))

# %%
def find_similar_users(user, df, metric="pearson"):
    """
        Given a user and a dataframe (optionally a similarity metric)
        this function finds users
    """
    
    sims = similirity_evaluation(user, df, metric)
    results = pd.DataFrame([df.index, sims.ravel()],
                           index=["Users", "Similarity scores"]).T
    return results.sort_values("Similarity scores", ascending=False).reset_index(drop=True)

def find_similar_items(item, df, metric="cosine"):
    sims = similirity_evaluation(item, df.T, metric)
    results = pd.DataFrame([df.columns, sims.ravel()],
                           index=["Items", "Similarity scores"]).T
    return results.sort_values("Similarity scores", ascending=False).reset_index(drop=True)

# %%
i1 = get_user("User_8", complete)
i2 = get_user("User_11400", complete)
i3 = get_user(["User_11400", "User_67544"], complete)
i4 = get_user("User_67544", complete)

j1 = get_item(' Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))', complete)
j2 = get_item('"A" is for Alibi : A Kinsey Millhone Mystery (A Kinsey Millhone Mystery)', complete)
j3 = get_item(['Zodiac: The Eco-Thriller', 
               'Zoey Phillips (Girlfriends) (Harlequin Superromance, No. 1020)',], complete)
j4 = get_item(['\'Salem\'s Lot', '"O" Is for Outlaw', 
              ' Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))'], complete)
j5 = get_item('Harry Potter and the Chamber of Secrets (Book 2)',complete)

(compute_evaluation_metric(i1, i2, "RMSE"), compute_evaluation_metric(i1, i2, "MAE"),
 compute_evaluation_metric(i1, i2, "MSE"))
# Out:
# (5.0, 5.0, 25.0)

# %%
sims = similirity_evaluation(get_item('Harry Potter and the Chamber of Secrets (Book 2)',complete),
                      complete.T, "cosine")
sims
# Out:
# array([[4.41018016e-11, 4.14264303e-11, 9.01698410e-11, ...,
#         2.90427559e-11, 4.05922560e-11, 2.91007505e-02]])

# %%
user_itempreds = predict_user_ratings(i2, complete)
sims = similirity_evaluation(i2, complete)

# %%
test = pd.DataFrame(np.vstack((user_itempreds, i2, complete.columns))).T
test
# Out:
#              0    1                                                  2
# 0      3.05291  NaN   Murder of a Sleeping Beauty (Scumble River My...
# 1      3.05475  NaN   Q-Space (Star Trek The Next Generation, Book 47)
# 2      3.04952  NaN    Q-Zone (Star Trek The Next Generation, Book 48)
# 3      3.05561  NaN  " Lamb to the Slaughter and Other Stories (Pen...
# 4      3.05374  NaN  "A" is for Alibi : A Kinsey Millhone Mystery (...
# 5      3.03652  NaN                                  "O" Is for Outlaw
# 6      3.05637  NaN  "Surely You're Joking, Mr. Feynman!": Adventur...
# 7      3.04657  NaN  "The Happy Prince" and Other Stories (Penguin ...
# 8      3.05444  NaN                                       'Salem's Lot
# 9      3.04748  NaN  ...AND THE HORSE HE RODE IN ON : THE PEOPLE V....
# 10     3.04779  NaN              01-01-00: The Novel of the Millennium
# 11     3.05064  NaN                 1,000 Places to See Before You Die
# 12      3.0467  NaN                                     10 Lb. Penalty
# 13     3.05532  NaN                           1001 Ways to Be Romantic
# 14     3.05263  NaN                     1001 Ways to Cut Your Expenses
# 15     3.05626  NaN           101 Best Home-Based Businesses for Women
# 16     3.06113  NaN                                     101 Dalmatians
# 17      3.0515  NaN   101 Great American Poems (Dover Thrift Editions)
# 18      3.0522  NaN                     101 Hopelessly Hilarious Jokes
# 19      3.0522  NaN                                   101 School Jokes
# 20     3.05666  NaN                         101 Silly Summertime Jokes
# 21      3.0522  NaN              13th Gen: Abort, Retry, Ignore, Fail?
# 22     3.06267  NaN                    14,000 Things to Be Happy About
# 23     3.04315  NaN                                 16 Lighthouse Road
# 24      3.0514  NaN                   1632 (Assiti Shards (Paperback))
# 25     3.05523  NaN                          1812 (The American Story)
# 26     3.05034  NaN                                         18Mm Blues
# 27     3.04882  NaN  1916: A Novel of the Irish Rebellion (Irish Ce...
# 28     3.09358  NaN                                               1984
# 29     3.05263  NaN                          1984 (Everyman's Library)
# ...        ...  ...                                                ...
# 13120  3.06089  NaN  Your Oasis on Flame Lake (Ballantine Reader's ...
# 13121  3.05395  NaN  Your Pregnancy: Week by Week (Your Pregnancy S...
# 13122  3.05609  NaN  Your Sixth Sense: Unlocking the Power of Your ...
# 13123  3.06844  NaN                                    Youth in Revolt
# 13124  3.05731  NaN                                          Yukon Ho!
# 13125  3.05482  NaN                    Yuletide Brides (2 Novels in 1)
# 13126  3.05667  NaN                                    Z for Zachariah
# 13127    3.052  NaN                                       ZEKE AND NED
# 13128  3.05263  NaN                                      Zeit im Wind.
# 13129  3.05165  NaN                                       Zeke and Ned
# 13130  3.04515  NaN                                       Zen Attitude
# 13131  3.05263  NaN          Zen and the Art of Motorcycle Maintenance
# 13132  3.04558  NaN  Zen and the Art of Motorcycle Maintenance: An ...
# 13133   3.0496  NaN  Zen and the Art of Murder (St. Martin's Minota...
# 13134  3.06393  NaN                          Zen in the Art of Writing
# 13135  3.05348  NaN                                   Zero at the Bone
# 13136  3.05241  NaN                                                Zia
# 13137  3.04809  NaN          Zlata's Diary: A Child's Life in Sarajevo
# 13138  3.06008  NaN           Zlata's Diary: A Childs Life in Sarajevo
# 13139  3.04787  NaN                                             Zodiac
# 13140  3.05345  NaN                           Zodiac: The Eco-Thriller
# 13141  3.04556  NaN  Zoey Phillips (Girlfriends) (Harlequin Superro...
# 13142  3.05427  NaN                           Zombies of the Gene Pool
# 13143  3.05124  NaN                                               Zoya
# 13144  3.04853  NaN  Zoya's Story: An Afghan Woman's Struggle for F...
# 13145  3.05385  NaN                                          ZwÃ?Â¶lf.
# 13146  3.06345  NaN                                                  e
# 13147  3.05263  NaN                            iI Paradiso Degli Orchi
# 13148  3.05037  NaN                      one hundred years of solitude
# 13149  3.04704  NaN                                           stardust
#
# [13150 rows x 3 columns]

# %%
for user in complete.index[:5]:
    u = get_user(user, complete)
    user_itempreds = predict_user_ratings(u, complete)
    sims = similirity_evaluation(u, complete)
    
    dummy_scorer = compute_evaluation_metric(u, np.ones(u.shape)*np.nanmean(u))
    model_scorer = compute_evaluation_metric(u, user_itempreds)
    
    print(f"{user}:\n\tDummy: {dummy_scorer}\n\tModel: {model_scorer}\n")
# Out:
# User_100004:
# 	Dummy: 23.140495867768596
# 	Model: 18.278362220126084
#
# User_100009:
# 	Dummy: 16.53333333333333
# 	Model: 15.091299868063858
#
# User_10001:
# 	Dummy: 13.88888888888889
# 	Model: 7.741781488302394
#
# User_100010:
# 	Dummy: 0.0
# 	Model: 6.521531911340406e-06
#
# User_100038:
# 	Dummy: 0.0
# 	Model: 3.7623095072846116e-05

# %%
find_similar_items(j5, complete, "cosine")
# Out:
#                                                    Items Similarity scores
# 0       Harry Potter and the Chamber of Secrets (Book 2)                 1
# 1      Harry Potter and the Prisoner of Azkaban (Book 3)          0.578975
# 2           Harry Potter and the Goblet of Fire (Book 4)          0.569977
# 3         Harry Potter and the Sorcerer's Stone (Book 1)          0.451425
# 4      Harry Potter and the Order of the Phoenix (Boo...          0.361031
# 5      Harry Potter and the Sorcerer's Stone (Harry P...          0.346424
# 6      The Fellowship of the Ring (The Lord of the Ri...          0.160708
# 7                    The Hobbit: or There and Back Again          0.135877
# 8      Dr. Seuss's A B C (I Can Read It All by Myself...          0.119482
# 9            Ramona the Pest (Ramona Quimby (Paperback))          0.119221
# 10                      Charlotte's Web (Trophy Newbery)          0.117581
# 11                The Canterbury Tales (Bantam Classics)          0.117202
# 12                                          Lover Beware          0.116424
# 13     The Reptile Room (A Series of Unfortunate Even...           0.11556
# 14     The Bad Beginning (A Series of Unfortunate Eve...          0.112337
# 15                                       The Giving Tree          0.108853
# 16        The Two Towers (The Lord of the Rings, Part 2)          0.106645
# 17                                       A Dash of Death          0.106326
# 18     Bard: The Odyssey of the Irish (Celtic World o...          0.105825
# 19     Dragons of a Fallen Sun (Dragonlance: The War ...          0.105569
# 20                                      The Silmarillion           0.10523
# 21     The Hobbit : The Enchanting Prelude to The Lor...          0.104671
# 22       Test of the Twins (Dragonlance Legends, Vol. 3)          0.104109
# 23                                         The Outsiders          0.103136
# 24     Charlie and the Great Glass Elevator (Puffin N...           0.10255
# 25            Kissed by Shadows (Get Connected Romances)          0.102291
# 26         J. K. Rowling: The Wizard Behind Harry Potter          0.102238
# 27     The Secret of the Indian (Indian in the Cupboard)          0.101029
# 28     The Shelters of Stone (Earth's Children Series...         0.0996812
# 29     The Vile Village (A Series of Unfortunate Even...         0.0988361
# ...                                                  ...               ...
# 13120                                             Shogun       1.69514e-11
# 13121                   Life,the Universe and Everything       1.68977e-11
# 13122                                          Prime Cut       1.67762e-11
# 13123                   Revenge of the Middle-Aged Woman       1.67489e-11
# 13124  The Artist's Way : A Spiritual Path to Higher ...       1.67347e-11
# 13125            Northern Lights (His Dark Materials S.)       1.66923e-11
# 13126                                      Reap the Wind       1.66085e-11
# 13127                                      Guilty as Sin       1.66039e-11
# 13128                                      Shell Seekers       1.65717e-11
# 13129  The Purpose-Driven Life: What on Earth Am I He...       1.64943e-11
# 13130                                      Morning Glory        1.6347e-11
# 13131                                   The Last Suppers         1.629e-11
# 13132                                       Dragon Tears       1.62412e-11
# 13133                                         Snow Crash       1.61269e-11
# 13134                             Writing Down the Bones       1.60806e-11
# 13135  A Beautiful Mind: The Life of Mathematical Gen...       1.59933e-11
# 13136  Portrait of a Killer: Jack the Ripper -- Case ...       1.59768e-11
# 13137                                       Grand Avenue        1.5875e-11
# 13138  Pride and Prejudice (The Penguin English Libra...       1.58069e-11
# 13139                                          Contagion       1.57751e-11
# 13140  The Green Mile: Night Journey (Green Mile Series)       1.57239e-11
# 13141  The Green Mile: Coffey's Hands (Green Mile Ser...       1.53826e-11
# 13142                                         Dead Sleep       1.52451e-11
# 13143      The Dress Lodger (Ballantine Reader's Circle)       1.46655e-11
# 13144                             The General's Daughter       1.39408e-11
# 13145                                     Oryx and Crake       1.37038e-11
# 13146             The Two Dead Girls (Green Mile Series)       1.35583e-11
# 13147                               White Teeth: A Novel       1.35034e-11
# 13148  The Curious Incident of the Dog in the Night-T...       1.20266e-11
# 13149                               The Door to December       1.19657e-11
#
# [13150 rows x 2 columns]

# %%
# %%timeit
find_similar_items(j5, complete, "cosine")
# Out:
# 2.5 s ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
find_similar_items(j5, complete, "pearson")
# Out:
# 4.54 s ± 42.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
find_similar_users(i1, complete, "cosine")
# Out:
#              Users Similarity scores
# 11487       User_8           0.99996
# 10849   User_67544          0.398504
# 814    User_116866          0.311829
# 5755   User_219008          0.275409
# 8030   User_263325          0.134908
# 808     User_11676         0.0200369
# 10734   User_65322            0.0001
# 9782    User_46133            0.0001
# 4889   User_201634            0.0001
# 7006   User_243200            0.0001
# 10737   User_65338            0.0001
# 1838   User_137939            0.0001
# 7548    User_25281            0.0001
# 1830   User_137630            0.0001
# 8741   User_276954            0.0001
# 6115   User_226031            0.0001
# 9626    User_42601            0.0001
# 11805   User_86231            0.0001
# 11820   User_86538            0.0001
# 10732   User_65270            0.0001
# 7691   User_255911            0.0001
# 1811   User_137302            0.0001
# 1808   User_137279            0.0001
# 11827   User_86683            0.0001
# 4910   User_201898            0.0001
# 8026    User_26326            0.0001
# 8748   User_277087            0.0001
# 1791   User_136858            0.0001
# 8733   User_276856            0.0001
# 1856   User_138228            0.0001
# ...            ...               ...
# 6625   User_236283       1.85623e-10
# 11429   User_78973       1.85248e-10
# 6062   User_225087       1.84657e-10
# 3777   User_177432       1.84247e-10
# 8168   User_265889       1.82703e-10
# 8580   User_274061       1.81027e-10
# 44     User_100906       1.79954e-10
# 7807   User_258534       1.79475e-10
# 11314   User_76499       1.77793e-10
# 11152    User_7346       1.77022e-10
# 6780    User_23902       1.75189e-10
# 9055    User_31826       1.74787e-10
# 2789   User_158295       1.74376e-10
# 3005   User_162639       1.74039e-10
# 3983   User_182085       1.71076e-10
# 11290   User_76151        1.7056e-10
# 9022    User_31315       1.67727e-10
# 574    User_112001       1.64253e-10
# 9265    User_35859       1.56309e-10
# 1673   User_135149       1.56001e-10
# 10479   User_60244        1.5474e-10
# 683    User_114368       1.49291e-10
# 6563   User_235105       1.46746e-10
# 7744   User_257204       1.40698e-10
# 5067   User_204864       1.37628e-10
# 206    User_104636       1.29837e-10
# 12281   User_95359       1.26473e-10
# 3276    User_16795       1.22872e-10
# 2582   User_153662       9.27218e-11
# 12403   User_98391       7.19376e-11
#
# [12490 rows x 2 columns]

# %%
# %%timeit
find_similar_users(i1, complete, "cosine")
# Out:
# 2.49 s ± 7.81 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
find_similar_users(i1, complete, "pearson")
# Out:
# 4.41 s ± 10.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### User-based tests:

# %%
similirity_evaluation(i1, i3, "pearson")
# Out:
# array([[-0.09138566,  0.13498689]])

# %%
similirity_evaluation(i1, i3, "cosine")
# Out:
# array([[6.62261793e-10, 3.98504416e-01]])

# %%
# %%timeit
cos_sim(i1, i3)
# Out:
# 148 µs ± 2.54 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
pearson_sim(i1, i3)
# Out:
# 500 µs ± 2.73 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
similirity_evaluation(i1, i3, "cosine")
# Out:
# 157 µs ± 1.22 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
similirity_evaluation(i1, i3, "pearson")
# Out:
# 509 µs ± 2.07 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Item-based tests:

# %%
similirity_evaluation(j2, j4, "pearson")
# Out:
# array([[-0.06359102,  0.02868645,  0.00793028]])

# %%
similirity_evaluation(j2, j4, "cosine")
# Out:
# array([[1.16175623e-10, 8.09315160e-11, 1.24607297e-02]])

# %%
# %%timeit
similirity_evaluation(j2, j4, "cosine")
# Out:
# 635 µs ± 8.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
similirity_evaluation(j2, j4, "pearson")
# Out:
# 1.36 ms ± 23 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# 505             NaN
# 507             NaN
# 566             NaN
# 567             NaN
# 625             NaN
# 626             NaN
# 638             NaN
# 643             NaN
# 651             NaN
# 709             NaN
# 728             NaN
# 735             NaN
# 741             NaN
# 805             NaN
# 834             NaN
# 843             NaN
# 850             NaN
# ...             ...
# 278012          NaN
# 278026          NaN
# 278044          NaN
# 278054          NaN
# 278064          NaN
# 278137          NaN
# 278144          NaN
# 278188          NaN
# 278194          NaN
# 278202          NaN
# 278218          NaN
# 278221          NaN
# 278314          NaN
# 278342          NaN
# 278346          NaN
# 278356          NaN
# 278390          NaN
# 278418          NaN
# 278506          NaN
# 278522          NaN
# 278535          NaN
# 278536          NaN
# 278554          NaN
# 278563          NaN
# 278582          NaN
# 278633          NaN
# 278637          NaN
# 278771          NaN
# 278843          NaN
# 278851          NaN
#
# [12490 rows x 38 columns]

# %%
ff3.shape
# Out:
# (12490, 38)

# %%
# drop rows and columns with less than 5 common ratings
nnans3 = ff3.dropna(thresh=2, axis=1).dropna(thresh=2, axis=0)
nnans3
# Out:
# ISBN     0002005018  0060084405  0060175532  0060512822  0060958022  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         7.0         NaN
# 1848            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2333            NaN         NaN         NaN         NaN         NaN
# 2766            NaN         NaN         NaN         NaN         8.0
# 3363            NaN         NaN         NaN         NaN         0.0
# 3373            NaN         NaN         NaN         NaN         0.0
# 4017            NaN         NaN         NaN         NaN         NaN
# 5903            NaN         NaN         NaN         NaN         NaN
# 6242            NaN         NaN         NaN         NaN         6.0
# 6251            NaN         NaN         NaN         NaN         NaN
# 6543            NaN         NaN         NaN         NaN         NaN
# 6563            NaN         NaN         NaN         NaN         NaN
# 6575            NaN         NaN         NaN         NaN         0.0
# 6900            NaN         NaN         NaN         NaN         NaN
# 7125            NaN         NaN         NaN         NaN         NaN
# 7158            NaN         NaN         NaN         NaN         NaN
# 7283            NaN         NaN         NaN         NaN         NaN
# 7346            NaN         NaN         NaN         NaN         NaN
# 7620            NaN         NaN         NaN         NaN         NaN
# 7915            NaN         NaN         NaN         NaN         NaN
# 8245            NaN         NaN         NaN         NaN         NaN
# 8253            NaN         NaN         NaN         NaN         NaN
# 8362            NaN         NaN         NaN         NaN         NaN
# 8681            NaN         NaN         NaN         NaN         0.0
# 9747            NaN         NaN         NaN         NaN         NaN
# 10030           NaN         NaN         NaN         NaN         NaN
# 10314           NaN         9.0         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 267061          NaN         NaN         NaN         NaN         NaN
# 268030          NaN         NaN         NaN         NaN         NaN
# 268032          NaN         NaN         NaN         NaN         NaN
# 268110          NaN         NaN         NaN         NaN         NaN
# 268330          NaN         NaN         NaN         NaN         NaN
# 268589          NaN         NaN         NaN         NaN         NaN
# 268622          NaN         NaN         NaN         NaN         NaN
# 269566          NaN         NaN         NaN         NaN         NaN
# 269719          NaN         NaN         NaN         NaN         NaN
# 269808          NaN         NaN         NaN         NaN         NaN
# 270554          NaN         NaN         NaN         NaN         NaN
# 270605          NaN         NaN         NaN         NaN         NaN
# 270713          NaN         NaN         NaN         NaN         NaN
# 270820          NaN         NaN         NaN         NaN         NaN
# 271176          NaN         NaN         NaN         9.0         NaN
# 271284          NaN         NaN         NaN         NaN         NaN
# 275970          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 277937          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# ISBN     1853261912
# User-ID
# 254             NaN
# 882             NaN
# 1424            NaN
# 1848            NaN
# 2110            NaN
# 2333            NaN
# 2766            NaN
# 3363            NaN
# 3373            NaN
# 4017            NaN
# 5903            NaN
# 6242            NaN
# 6251            NaN
# 6543            NaN
# 6563            NaN
# 6575            NaN
# 6900            NaN
# 7125            NaN
# 7158            NaN
# 7283            NaN
# 7346            NaN
# 7620            NaN
# 7915            NaN
# 8245            NaN
# 8253            NaN
# 8362            NaN
# 8681            NaN
# 9747            NaN
# 10030           NaN
# 10314           NaN
# ...             ...
# 267061          NaN
# 268030          NaN
# 268032          NaN
# 268110          NaN
# 268330          NaN
# 268589          NaN
# 268622          NaN
# 269566          NaN
# 269719          NaN
# 269808          NaN
# 270554          NaN
# 270605          NaN
# 270713          NaN
# 270820          NaN
# 271176          NaN
# 271284          NaN
# 271448          NaN
# 271538          NaN
# 271558          NaN
# 271705          NaN
# 273307          NaN
# 273535          NaN
# 273979          NaN
# 274004          NaN
# 274056          NaN
# 274549          NaN
# 275970          NaN
# 277639          NaN
# 277937          NaN
# 278418          NaN
#
# [883 rows x 38 columns]

# %%
nnans3.shape
# Out:
# (883, 38)

# %%
# Find the similarity between the new vector and the candidates
i2_short = nnans3.loc[:,"0151008116"]
similirity_evaluation(i2_short, nnans3.T, "cosine").round(2)
# Out:
# array([[0.11, 0.  , 0.  , 0.07, 0.11, 0.06, 0.  , 1.  , 0.18, 0.02, 0.12,
#         0.07, 0.05, 0.09, 0.  , 0.  , 0.03, 0.06, 0.18, 0.18, 0.1 , 0.  ,
#         0.01, 0.05, 0.05, 0.03, 0.08, 0.  , 0.08, 0.  , 0.07, 0.04, 0.12,
#         0.12, 0.13, 0.13, 0.14, 0.  ]])

# %%
similirity_evaluation(i2_short, nnans3.loc[:,"0151008116"].T, "cosine").round(2)
# Out:
# array([[0.11]])

# %%
nnans3.shape, i2_short.shape
# Out:
# ((883, 38), (883,))

# %%
# check original (only common values) to see if 0.44 correlation appears plausible 
complete.loc[:,["0060958022","0151008116"]].dropna(thresh=2, axis=0)
# Out:
# ISBN     0060958022  0151008116
# User-ID
# 11400          10.0         6.0
# 11676           3.0         6.0
# 43246           0.0         0.0
# 98741           0.0         0.0
# 113519          8.0         9.0
# 114868          0.0         0.0
# 139742          0.0         0.0
# 172742          0.0         0.0
# 201290          0.0         0.0
# 264317          0.0         0.0
# 271705          7.0         9.0

# %%
ii1 = complete.dropna(thresh=2, axis=0).T.values
pearsonr(ii1[0,:], ii1[1,:])
# Out:
# (nan, 1.0)

# %%
ii1.shape
# Out:
# (14755, 11931)

# %%
predict_i(i1, complete.values)
# Out:
# array([5.10557647, 2.5       , 2.3248965 , ..., 2.5       , 2.5       ,
#        2.5       ])

# %%
predict_i(i2, complete.values)
# Out:
# array([3.00031253, 3.06117812, 3.04107743, ..., 3.05825516, 3.06124779,
#        3.05160399])

# %%
predict_i(i4, complete)
# Out:
# array([6.76274148, 6.625     , 6.61740402, ..., 6.625     , 6.64395034,
#        6.63900064])

# %%
pj1 = predict_i(get_item("0060958022"), complete.T.values)
pj1
# Out:
# array([3.28665504, 3.28701045, 3.28753367, ..., 3.28563866, 3.28397332,
#        3.28902673])

# %%
pj1.max(), pj1.min()
# Out:
# (5.749083253619088, 3.0239473786652513)

# %%
pj2 = predict_i(get_item("0151008116"), complete.T.values)
pj2
# Out:
# array([4.17182472, 4.17182336, 4.17366063, ..., 4.16760712, 4.17522016,
#        4.1735431 ])

# %%
pj2.max(), pj2.min()
# Out:
# (6.678546628117268, 3.9005324537219246)

# %%
pj2 = predict_i(get_item("0151008116"), complete.T.values)
pj2
# Out:
# array([4.17182472, 4.17182336, 4.17366063, ..., 4.16760712, 4.17522016,
#        4.1735431 ])

# %%
preds = predict_i(i2_short, nnans3.T)
preds
# Out:
# array([3.25771254, 3.15944676, 3.28837306, 3.60032211, 3.69521197,
#        3.59819321, 3.45268945, 3.01250799, 3.4767577 , 3.07625759,
#        3.07192041, 3.65018902, 3.03111267, 2.30878096, 3.81809197,
#        3.1903585 , 3.16149781, 4.00726237, 2.18888988, 3.20429946,
#        3.24694719, 3.71515639, 3.93581135, 3.55492262, 3.23461876,
#        2.36959207, 3.39089289, 3.06199426, 3.17407433, 3.70178995,
#        3.2847156 , 3.80698116, 5.03280303, 3.28568041, 6.26741684,
#        3.2514888 , 3.59133727, 3.63270423, 2.22733659, 3.73486387,
#        3.62608575, 3.40048946, 3.14417427, 2.88790841, 3.28241253,
#        3.5056749 , 3.15691557, 3.04741394, 3.83755428, 7.42219818,
#        3.32384496, 3.30654764, 3.43129087, 3.1835838 , 3.74798546,
#        3.17888678, 3.33788524, 3.16149781, 3.42508768, 3.53569926,
#        3.64214881, 2.55892388, 3.49219069, 3.1907591 , 3.31094932,
#        3.78381863, 3.2478728 , 3.72279069, 3.63115602, 2.74138293,
#        3.3205056 , 3.47809287, 3.59898504, 3.7230413 , 3.52081465,
#        3.27897154, 3.83681673, 3.12265693, 3.25641912, 3.3736617 ,
#        3.22611553, 2.94688008, 3.6730194 , 3.17882476, 3.03229413,
#        3.7554754 , 1.91924654, 3.1502067 , 3.914042  , 3.41384343,
#        2.55058968, 3.78941401, 3.52299694, 3.47879483, 3.09800187,
#        3.32224306, 3.43863913, 3.58355477, 3.33648397, 3.6332902 ,
#        3.28151759, 3.04305465, 3.52859313, 3.53893261, 3.06199426,
#        3.4683185 , 2.29130578, 3.53946698, 3.32912789, 3.16652532,
#        2.72230644, 3.78536548, 3.66514736, 3.50650746, 3.46607775,
#        3.05522613, 3.65782088, 3.1907591 , 4.60096389, 3.30056042,
#        2.68555332, 3.36508608, 3.11516064, 5.53487694, 3.42060868,
#        3.25895031, 3.29705097, 2.09105138, 3.73806031, 4.58103095,
#        3.15691557, 3.82335262, 3.4123833 , 3.14101271, 3.44681706,
#        3.73895611, 3.32379189, 3.64948376, 3.28568041, 2.35888918,
#        3.02437727, 3.04305465, 3.06199426, 3.41236138, 3.17407433,
#        3.66848794, 3.59301758, 3.69493793, 3.3191628 , 3.80698116,
#        3.36323506, 3.27002627, 3.23453864, 3.25933697, 3.4093686 ,
#        3.33648397, 3.60361929, 3.54402096, 3.21197899, 3.44338738,
#        3.87091471, 3.31205136, 3.60179457, 3.81140541, 3.09400949,
#        3.08520528, 5.01651798, 3.15849143, 3.12046912, 3.60234246,
#        3.13940873, 3.3297751 , 3.28168802, 3.23073319, 3.2629427 ,
#        3.80002233, 3.52929886, 5.38126404, 3.23073319, 3.55756136,
#        3.34717254, 3.27130484, 3.44980298, 3.17407433, 3.33648397,
#        3.38760736, 3.4783718 , 2.76505723, 3.88039041, 3.45047213,
#        3.17066446, 3.432073  , 3.15940247, 3.02236799, 3.3039357 ,
#        3.55811229, 3.34717254, 3.91046923, 2.99013469, 3.33236289,
#        3.21700888, 3.41976978, 3.32330491, 3.30283917, 3.14880543,
#        2.94916364, 3.47864903, 3.31094932, 3.61709252, 3.21629375,
#        3.05123374, 3.30492   , 2.40967999, 3.14820258, 3.19255618,
#        1.94375611, 3.47585638, 3.27529151, 3.14135701, 3.24160011,
#        3.28568041, 3.20212966, 3.16855161, 3.08659017, 3.13940873,
#        3.19735414, 2.93755612, 3.6301323 , 3.36175287, 3.01300671,
#        3.28732652, 3.17476516, 3.19064527, 3.19459753, 3.49913005,
#        3.23101217, 3.27617299, 3.58082753, 3.52975668, 3.66162986,
#        3.60620415, 3.79831461, 3.58171579, 3.3297751 , 3.81920615,
#        3.25641912, 3.23509247, 5.20466984, 3.28568041, 3.2496728 ,
#        3.39298499, 3.44534944, 3.66218942, 3.35951729, 3.15427809,
#        3.36622615, 3.23154976, 3.30450619])

# %%
preds.max(), preds.mean(), preds.min(), preds.std()
# Out:
# (7.422198182599594, 3.3698630136986303, 1.6851247135632899, 0.4790006614074269)

# %%
preds.argmax() # who is the "closest user" (in essense, who is the user most likely to rate this well)
# Out:
# 49

# %%
nnans3.iloc[49]
# Out:
# ISBN
# 0002005018     NaN
# 0060084405     NaN
# 0060175532     NaN
# 0060512822     NaN
# 0060958022     NaN
# 0140126562     NaN
# 0140430016     NaN
# 0151008116    10.0
# 0312195516     9.0
# 0312274920     NaN
# 0312305060     8.0
# 0312978383     6.0
# 0316789089     NaN
# 0345445848     0.0
# 0345445856     NaN
# 0375504036     NaN
# 0375506039     NaN
# 0375724850     NaN
# 0375727345     9.0
# 0380723085    10.0
# 0385333412     NaN
# 0425116840     0.0
# 0440211727     0.0
# 0440222656     9.0
# 0446364193     8.0
# 0446606324     0.0
# 0449003981     NaN
# 0553582658     0.0
# 0671021001    10.0
# 067166641X     NaN
# 0679449434     NaN
# 0743225325     NaN
# 074341134X    10.0
# 0743418174     9.0
# 0786868716     8.0
# 1551664992     NaN
# 1552781542     NaN
# 1853261912     NaN
# Name: 16795, dtype: float64

# %%
nnans3.iloc[49]["0151008116"] # seems legit
# Out:
# 10.0

# %%
similirity_evaluation(get_item("0151008116"), get_item("0380723085"), "cosine")
# Out:
# array([[0.11914448]])
